# %% [markdown]
# ### Performance Analysis of Code

# %%
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Test Multiple Imputation running time

# %%
from utils.data import create_adult_dataset
from utils.generator import gen_complete_random
from utils.completer import complete_by_multi, complete_by_multi_v2
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import KNNImputer, IterativeImputer

# %%
data = create_adult_dataset()
data_incomplete = gen_complete_random(data, random_ratio=0.95)
# Out:
# ...
# gen_complete_random: 253888 NaN values have been inserted

# %%
# test time for multi_v1
data_complete_v1 = complete_by_multi(data_incomplete, print_time=True, verbose=2)
# Out:
# [IterativeImputer] Completing matrix with shape (32561, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 13.49
# [IterativeImputer] Completing matrix with shape (32561, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 13.50
# [IterativeImputer] Completing matrix with shape (32561, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 13.43
# [IterativeImputer] Completing matrix with shape (32561, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 13.49
# [IterativeImputer] Completing matrix with shape (32561, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 13.20
# [IterativeImputer] Completing matrix with shape (32561, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 13.54
# [IterativeImputer] Completing matrix with shape (32561, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 13.57
# [IterativeImputer] Completing matrix with shape (32561, 9)
# ...

# %%
data_complete_v2 = complete_by_multi_v2(data_incomplete, print_time=True, verbose=2, target_feature="sex")
# Out:
# [IterativeImputer] Completing matrix with shape (10771, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 4.50
# [IterativeImputer] Completing matrix with shape (21790, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 9.32
# [IterativeImputer] Completing matrix with shape (21790, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 9.16
# [IterativeImputer] Completing matrix with shape (10771, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 4.47
# [IterativeImputer] Completing matrix with shape (10771, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 4.54
# [IterativeImputer] Completing matrix with shape (21790, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 9.02
# [IterativeImputer] Completing matrix with shape (21790, 9)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 9.03
# [IterativeImputer] Completing matrix with shape (10771, 9)
# ...

# %%
data_incomplete.X.head()
# Out:
#    age  workclass  education  education-num  marital-status  occupation  \
# 0  NaN        NaN        NaN            NaN             NaN         NaN
# 1  NaN        NaN        NaN            NaN             2.0         NaN
# 2  NaN        NaN        NaN            NaN             0.0         NaN
# 3  NaN        NaN        NaN            NaN             NaN         6.0
# 4  NaN        4.0        NaN            NaN             NaN         NaN
#
#    relationship  race  hours-per-week      sex
# 0           NaN   4.0             NaN     Male
# 1           NaN   NaN             NaN     Male
# 2           NaN   NaN             NaN     Male
# 3           NaN   NaN             NaN     Male
# 4           NaN   NaN             NaN   Female

# %%
data.X.head()
# Out:
#    age  workclass  education  education-num  marital-status  occupation  \
# 0   39          7          9             13               4           1
# 1   50          6          9             13               2           4
# 2   38          4         11              9               0           6
# 3   53          4          1              7               2           6
# 4   28          4          9             13               2          10
#
#    relationship  race      sex  hours-per-week
# 0             1     4     Male              40
# 1             0     4     Male              13
# 2             1     4     Male              40
# 3             0     2     Male              40
# 4             5     2   Female              40

# %%
from IPython.display import display
for i in range(len(data_complete_v1)):
    print("Round {}".format(i))
    print("V1:")
    display(data_complete_v1[i].X.head())
    print("V2:")
    display(data_complete_v2[i].X.head())
# Out:
# Round 0
# V1:
#    age  workclass  education  education-num  marital-status  occupation  \
# 0   24          2         19             15               3          11
# 1   38          3          9              8               2          10
# 2   53          3          7             10               0          11
# 3   57          3          9              6               1           6
# 4   31          4          8             12               2           5
#
#    relationship  race  hours-per-week      sex
# 0             3     4              45     Male
# 1             2     3              35     Male
# 2             1     3              16     Male
# 3             2     2              36     Male
# 4             2     4              24   Female
# V2:
#    age  workclass  education  education-num  marital-status  occupation  \
# 0   47          5          5              6               2           6
# 1   44          5          3              9               2           9
# ...
